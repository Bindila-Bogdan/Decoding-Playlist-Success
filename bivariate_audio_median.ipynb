# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pyspark import SparkContext
from pyspark.sql import SparkSession

# %%
sc = SparkContext(appName="webApp")
sc.setLogLevel("ERROR")
spark = SparkSession(sc).builder.getOrCreate()

# %%
df = spark.read.csv(r"D:\NirwanaWarehouse\uniMiscellaneous\GEXP\ManagingBigData\Project\Decoding-Playlist-Success\aggregated_data\aggregated_audio_median")

# %%
df = df.toPandas()
df.columns = df.iloc[0]
df = df[1:]

# %%
# Correlation
df = df[df['num_followers'] != 'num_followers']

# %%
plt.figure(figsize=(12,5))
sns.heatmap(df.corr(),robust=True,annot=True, cmap='viridis')
plt.show()
